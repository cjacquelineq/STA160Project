# %%
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd
import numpy as np
from geopandas import GeoDataFrame
from shapely.geometry import Point
from descartes import PolygonPatch

# %%
# All states 2016
congressionaldistrictshp115 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cb_2016_us_cd115_500k/cb_2016_us_cd115_500k.shp")

# %%
congressionaldistrictshp114 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cb_2015_us_cd114_500k/cb_2015_us_cd114_500k.shp")

# %%
congressionaldistrictshp113 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cb_2013_us_cd113_500k/cb_2013_us_cd113_500k.shp")

# %%
congressionaldistrictshp111 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/gz_2010_us_500_11_5m/gz_2010_us_500_11_5m.shp")

# %%
congressionaldistrictshp110 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cd99_110_shp/cd99_110.shp")

# %%
congressionaldistrictshp109 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cd99_109_shp/cd99_109.shp")

# %%
congressionaldistrictshp108 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cd99_108_shp/cd99_108.shp")

# %%
congressionaldistrictshp107 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cd99_107_shp/cd99_107.shp")

# %%
congressionaldistrictshp106 = gpd.read_file("/Users/chenjingqi/Dropbox/College/2017 Spring/STA 160/Gerrymandering/Congressional Districts/Shapefiles/cd99_106_shp/cd99_106.shp")

# %% [markdown]
# ### North Carolina

# %%
# North Carolina
NC115 = congressionaldistrictshp115.loc[congressionaldistrictshp115[u'STATEFP'] == u'37']

# %%
NC114 = congressionaldistrictshp114.loc[congressionaldistrictshp114[u'STATEFP'] == u'37']

# %%
NC113 = congressionaldistrictshp113.loc[congressionaldistrictshp113[u'STATEFP'] == u'37']

# %%
NC111 = congressionaldistrictshp111.loc[congressionaldistrictshp111[u'STATE'] == u'37']

# %%
NC110 = congressionaldistrictshp110.loc[congressionaldistrictshp110[u'STATE'] == u'37']

# %%
NC109 = congressionaldistrictshp109.loc[congressionaldistrictshp109[u'STATE'] == u'37']

# %%
NC108 = congressionaldistrictshp108.loc[congressionaldistrictshp108[u'STATE'] == u'37']

# %%
NC107 = congressionaldistrictshp107.loc[congressionaldistrictshp107[u'STATE'] == u'37']

# %%
NC106 = congressionaldistrictshp106.loc[congressionaldistrictshp106[u'ST'] == u'37']

# %%
# Congressional district of North Carolina
plt.rcParams['figure.figsize'] = (20, 20)
NC115.plot()

# %%
NC114.plot()

# %%
NC113.plot()

# %%
NC111.plot()

# %%
NC110.plot()

# %%
NC109.plot()

# %%
NC108.plot()

# %%
NC107.plot()

# %%
NC106.plot()

# %%
MD115 = congressionaldistrictshp115.loc[congressionaldistrictshp115[u'STATEFP'] == u'24']

# %%
MD114 = congressionaldistrictshp114.loc[congressionaldistrictshp114[u'STATEFP'] == u'24']

# %%
MD113 = congressionaldistrictshp113.loc[congressionaldistrictshp113[u'STATEFP'] == u'24']

# %%
MD111 = congressionaldistrictshp111.loc[congressionaldistrictshp111[u'STATE'] == u'24']

# %%
MD110 = congressionaldistrictshp110.loc[congressionaldistrictshp110[u'STATE'] == u'24']

# %%
MD109 = congressionaldistrictshp109.loc[congressionaldistrictshp109[u'STATE'] == u'24']

# %%
MD108 = congressionaldistrictshp108.loc[congressionaldistrictshp108[u'STATE'] == u'24']

# %%
MD107 = congressionaldistrictshp107.loc[congressionaldistrictshp107[u'STATE'] == u'24']

# %%
MD106 = congressionaldistrictshp106.loc[congressionaldistrictshp106[u'ST'] == u'24']

# %%
MD115.plot()

# %%
MD114.plot()

# %%
MD113.plot()

# %%
MD111.plot()

# %%
MD110.plot()

# %%
MD109.plot()

# %%
MD108.plot()

# %%
MD107.plot()

# %%
MD106.plot()
